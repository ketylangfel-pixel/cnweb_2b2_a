# %% [markdown]
# <a href="https://colab.research.google.com/github/ketylangfel-pixel/cnweb_2b2_a/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fórmula da velocidade

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS/deltaT)
  return velMedia

# %% [markdown]
# ## Teste Serviço Nuvem: Velocidade Média

# %%
print("vm=", calculaVelMedia(30, 15))
# Out:
# vm= 2.0

# %% [markdown]
# ## Fórmula de açeleração

# %%
def calculaAceleracao(vf,vi, t):
  return(vf - vi) / t

# %% [markdown]
# ## Teste de Serviço: Fórmula de açeleração

# %%
 print("a =", calculaAceleracao(30, 10,5))
# Out:
# a = 4.0

# %% [markdown]
# ## Fórmulas do Movimento Uniforme

# %%
def movimentoUniforme(s0, v, t):
  return s0 + v * t
  print("s =", movimentoUniforme(0, 10,5))

# %% [markdown]
# ## Teste de movimento uniforme

# %%
  print("s =", movimentoUniforme(0, 10,5))
# Out:
# s = 50

# %% [markdown]
# ## Função horária do deslocamento

# %%
def calculaDesloc(inicialS, deltaT, v):
 d = inicialS + (v*deltaT)
rertun d
# Out:
#   File "/tmp/ipykernel_20019/1442852585.py", line 3
#     rertun d
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Teste de deslocamento

# %%
print("Deslocamento= ",calculaDesloc(0, 15, 30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20019/2800099943.py in <cell line: 0>()
# ----> 1 print("Deslocamento= ",calculaDesloc(0, 15, 30))
#
# NameError: name 'calculaDesloc' is not defined

# %% [markdown]
# ##Testes de Função : Horária de Deslocamento

# %% [markdown]
# ## Fórmulas do Movimento Uniformemente Variado

# %%
def velocidade(v0, a, t)
return v0 + a *t

# %% [markdown]
# ## Nova seção

# %% [markdown]
# ## Função horária da velocidade

# %% [markdown]
# ## Função horária da posição

# %% [markdown]
# ## Equação de Torricelli

# %% [markdown]
# ## Fórmula do movimento vertical
